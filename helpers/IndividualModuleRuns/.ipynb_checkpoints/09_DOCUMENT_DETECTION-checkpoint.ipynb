# %%
from google.cloud import vision
import io
import os
from google.oauth2 import service_account
import cv2
import numpy as np
import unicodedata

# %%
all_json = list ()

# %%
def detect_document(path):
    """
    Detects document features in an image.
    Arguments:
        path: path to the image file for which characters has to be detected
    """
    creds = service_account.Credentials.from_service_account_file ('../../credentials/Character Detection-208f08e77e7d.json')
    client = vision.ImageAnnotatorClient (
        credentials = creds
    )

    with io.open (path, 'rb') as image_file:
        content = image_file.read ()

    field = path.rsplit ("/")[-2]
    image = vision.types.Image (content = content)
    all_blocks = []
    response = client.document_text_detection (image = image)
    #     print(client)
    #     print("Response: {}".format(response))

    for page in response.full_text_annotation.pages:
        for block in page.blocks:
            block_info = {"Block_Confidence": block.confidence, "Paragraphs": []}
            #             print('\nBlock confidence: {}\n'.format(block.confidence))

            for paragraph in block.paragraphs:
                paragraph_info = {"Paragraph_Confidence": paragraph.confidence, "Words": []}
                #                 print('Paragraph confidence: {}'.format(
                #                     paragraph.confidence))

                for word in paragraph.words:
                    word_text = ''.join ([
                        symbol.text for symbol in word.symbols
                    ])
                    word_info = {"Word_Text": word_text, "Word_Confidence": word.confidence, "Symbols": []}

                    #                     print('Word text: {} (confidence: {})'.format(
                    #                         word_text, word.confidence))

                    for symbol in word.symbols:
                        symbol_info = {'Symbol_Text': symbol.text, 'Symbol_Confidence': symbol.confidence}
                        word_info["Symbols"].append (symbol_info)
                    #                         print('\tSymbol: {} (confidence: {})'.format(
                    #                             symbol.text, symbol.confidence))

                    paragraph_info["Words"].append (word_info)
                block_info["Paragraphs"].append (paragraph_info)
            all_blocks.append (block_info)

    data_list = []

    for rows in all_blocks:
        result = {}
        #         if "Block_Confidence" in rows and rows["Block_Confidence"]:
        #             result["block_confidence"] = rows["Block_Confidence"]
        if "Paragraphs" in rows and len (rows["Paragraphs"]) > 0:
            for paragraphs in rows["Paragraphs"]:
                if "Words" in paragraphs and len (paragraphs["Words"]) > 0:
                    word_confidence = []
                    word_text = []
                    for words in paragraphs["Words"]:
                        if "Word_Confidence" in words and words["Word_Confidence"] is not None:
                            word_confidence.append (words["Word_Confidence"])
                        if "Word_Text" in words and words["Word_Text"] is not None:
                            word_text.append (words["Word_Text"])
                result["word_confidence"] = min (word_confidence)
                result["word_text"] = "_".join (word_text)
                result["field"] = field
        data_list.append (result)
#     print (field)
    #     print(data_list)
    fields = np.unique (([li['field'] for li in data_list]))

    word_text = list ([li['word_text'] for li in data_list])
    # average word confidence
    word_confidences = sum ([li['word_confidence'] for li in data_list]) / len (
        [li['word_confidence'] for li in data_list])
    final_word_text = ''.join (word_text)

    result['field'] = fields[0]
    result['word_text'] = unicodedata.normalize ('NFKD', final_word_text).encode ('ascii', 'ignore')
    result['word_confidence'] = word_confidences

    all_json.append (result.copy ())
    # print (result)
    final_json = dict ()
    for i in all_json:
        #     print(i)
        #     print('')
        final_json[i['field'] + '_CONFIDENCE'] = i['word_confidence']
        final_json[i['field']] = i['word_text']
    print(final_json)
#     return final_json

# %%
def documentDetection(userId):
    l = []
    # user_id = url.rsplit("/")[-2]
    user_id = userId
    # user_id = "Sarita"
    rootDir = "../../temporaryResults/imageSegmented/" + user_id + "/"

    # creating a list of folders that exist in the root directory
    folderInPath = []
    imageFiles = []
    for a, b, c in os.walk (rootDir):
        #     print("directories: {}".format(b))
        #     print("filename {}".format(c))
        folderInPath.append (b)
    # print(folderInPath[0])

    # #creatng a list of images that have the same name as folder name i.e. the files that have been stitched
    # print(folderInPath)
    for a in folderInPath[0]:
        a = a + ".jpg"
        #     print(a)
        imageFiles.append (a)

    # print("imageFiles contain: {}".format(imageFiles))

    # print(imageFiles)
    for a, b, c in os.walk (rootDir):
        for i in imageFiles:
            if i in c:
                try:
                    img = cv2.imread (a + '/' + i)
                    #             plt.figure()
                    #             plt.imshow(img)
                    #                 print(i.rsplit(".")[0])
                    detect_document (a + '/' + i)
                    print(
                        "--------------------------------------------------------------------------------------------")
                except Exception as ex:
                    print (str (ex))

# %%
user_id = "Sarita"
documentDetection(userId=user_id)
# Out:
# {'mother_email_id': '--_----_-_-_--_---F---------ses...', 'mother_email_id_CONFIDENCE': 0.6904545487328009}
# --------------------------------------------------------------------------------------------
# {'mother_occupation_CONFIDENCE': 0.5850000083446503, 'mother_occupation': 'HOMS_e_WIFI:_--_-_--', 'mother_email_id': '--_----_-_-_--_---F---------ses...', 'mother_email_id_CONFIDENCE': 0.6904545487328009}
# --------------------------------------------------------------------------------------------
# {'total_marks': '500', 'mother_occupation_CONFIDENCE': 0.5850000083446503, 'mother_email_id': '--_----_-_-_--_---F---------ses...', 'mother_occupation': 'HOMS_e_WIFI:_--_-_--', 'total_marks_CONFIDENCE': 0.9599999785423279, 'mother_email_id_CONFIDENCE': 0.6904545487328009}
# --------------------------------------------------------------------------------------------
# ...

# %%
final_json = {
        "mother_email_id_CONFIDENCE": 0.43888889087571037,
        "mother_email_id": "-_-_-_-_-_--_-_-_-_-_--1--_------------=_=_=_=",
        "mother_occupation_CONFIDENCE": 0.4233333244919777,
        "mother_occupation": "-_._-_--HOUSEWIFE",
        "total_marks_CONFIDENCE": 0.949999988079071,
        "total_marks": "-",
        "first_name_CONFIDENCE": 0.8080000042915344,
        "first_name": "SNEHATI----",
        "last_name_CONFIDENCE": 0.48333333681027096,
        "last_name": "GHOUTHIAN--_-_--_--SZERESSE_HE",
        "mother_annual_income_CONFIDENCE": 0.6216666748126348,
        "mother_annual_income": "-_-_--_-|_-_-_-_----",
        "mother_last_name_CONFIDENCE": 0.6439999967813492,
        "mother_last_name": "--_-_--_--_--",
        "marks_obtained_CONFIDENCE": 0.4099999964237213,
        "marks_obtained": "U19_6",
        "previous_class_passing_year_CONFIDENCE": 0.3600000023841858,
        "previous_class_passing_year": "--_-_-_-_---_-_-_--_,",
        "father_mobile_number_CONFIDENCE": 0.3700000047683716,
        "father_mobile_number": "610___)",
        "father_occupation_CONFIDENCE": 0.699999988079071,
        "father_occupation": "PRIVATE_TOBI",
        "student_mobile_number_CONFIDENCE": 0.4712500059977174,
        "student_mobile_number": "--_--_---_-_-45845197-_._L1",
        "date_of_birth_CONFIDENCE": 0.7599999904632568,
        "date_of_birth": "23102004",
        "present_address_CONFIDENCE": 0.519090910018845,
        "present_address": "-T_:_TiT_:_--F--T--1--=-_---=--li/_1-------NEW_TILPAT_COLONY_HANI_PANTAL_Y_4_FENIL_PATI_COLOMYHMISPALLA_4-----",
        "father_first_name_CONFIDENCE": 0.47000000160187483,
        "father_first_name": "F-_-_-_-_--BHALWA_NT",
        "aadhar_number_CONFIDENCE": 0.6885714312749249,
        "aadhar_number": "!____Rg_x2",
        "percentage_of_disability_CONFIDENCE": 0.4475000109523535,
        "percentage_of_disability": "F_*_*-_*_-_*-___",
        "annual_fee_CONFIDENCE": 0.4000000059604645,
        "annual_fee": "-_",
        "father_annual_income_CONFIDENCE": 0.43666666684051353,
        "father_annual_income": "JE_-_-_-_------",
        "mother_first_name_CONFIDENCE": 0.6318181888623671,
        "mother_first_name": "--_-_-_-----_----_--TARATI",
        "father_email_id_CONFIDENCE": 0.43210526242067937,
        "father_email_id": "-----_._-_-------===F_-_-_-_-_-_-rl_|_|_||-_---_L-li-.-----_-_-_-_=_-=_====",
        "email_CONFIDENCE": 0.4921518994283073,
        "email": "-----_--====-_-_-_-_==I_'.._.--_-l_|_-_-_lineil__|_-_-_-_---_---_-_-_-----_:_--'-------------------------_------------:------i",
        "gender": "female",
        "number_of_brothers_sisters": "1",
        "religion": "hindu",
        "category": "general",
        "present_class": "11",
        "present_class_stream": "textfield,commerce,arts",
        "mode_of_course": "parttime",
        "type_of_student": "studentdayscholar",
        "bank_name_CONFIDENCE": 0.699999988079071,
        "bank_name": "Tour_Balik_Detalls_\"",
        "graduation_marks_obtained_CONFIDENCE": 0.4816666642824809,
        "graduation_marks_obtained": "-----mrinn",
        "graduation_passing_year_CONFIDENCE": 0.5291666664804021,
        "graduation_passing_year": "------------",
        "account_holder_name_CONFIDENCE": 0.3465384633208697,
        "account_holder_name": "|_._--_--_---FS----F_-_=_-_=--_-_-:--11-_-_-_-_-_-=_-_=-_--_-_-_---_-",
        "class_10_total_marks_CONFIDENCE": 0.27000001072883606,
        "class_10_total_marks": "+_-_-_-_-_-_-_-",
        "account_number_CONFIDENCE": 0.4526666688422362,
        "account_number": "11_-_-_-_-_-CE_-_-_=----_-|------_-|L",
        "post_graduation_passing_year_CONFIDENCE": 0.1599999964237213,
        "post_graduation_passing_year": "1",
        "relation_with_account_holder_CONFIDENCE": 0.534749998524785,
        "relation_with_account_holder": "|_|---_--_--_---_-_----------_-----_--|_|_|=-=...=_..-_-_-E-=--|_|_:-",
        "post_graduation_stream": "Science,Arts,OthersTextField"
    }

# %%
alphabets_only =['first_name','first_name_CONFIDENCE',
                 'last_name','last_name_CONFIDENCE',
                 'father_first_name','father_first_name_CONFIDENCE',
                 'father_last_name','father_last_name_CONFIDENCE',
                 'father_occupation','father_occupation_CONFIDENCE',
                 'mother_first_name','mother_first_name_CONFIDENCE',
                'mother_last_name','mother_last_name_CONFIDENCE',
                 'mother_occupation','mother_occupation_CONFIDENCE',
                 'bank_name','bank_name_CONFIDENCE',
                 'account_holder_name','account_holder_name_CONFIDENCE']

numeric_only = ['date_of_birth','date_of_birth_CONFIDENCE',
                'aadhar_number','aadhar_number_CONFIDENCE',
                'student_mobile_number','student_mobile_number_CONFIDENCE',
                'percentage_of_disability','percentage_of_disability_CONFIDENCE',
                'father_mobile_number','father_mobile_number_CONFIDENCE',
                'father_annual_income','father_annual_income_CONFIDENCE',
                'mother_mobile_number','mother_mobile_number_CONFIDENCE',
                'mother_annual_income','mother_annual_income_CONFIDENCE',
                'annual_fee','annual_fee_CONFIDENCE',
                'previous_class_passing_year','previous_class_passing_year_CONFIDENCE',
                'marks_obtained','marks_obtained_CONFIDENCE',
                'total_marks','total_marks_CONFIDENCE',
                'class_10_total_marks','class_10_total_marks_CONFIDENCE',
                'class_10_marks_obtained','class_10_marks_obtained_CONFIDENCE',
                'class_12_passing_year','class_12_passing_year_CONFIDENCE',
                'class_12_total_marks','class_12_passing_year_CONFIDENCE',
                'class_12_marks_obtained','class_12_marks_obtained_CONFIDENCE',
                'graduation_total_marks','graduation_total_marks_CONFIDENCE',
                'graduation_marks_obtained','graduation_marks_obtained_CONFIDENCE',
                'graduation_passing_year','graduation_passing_year_CONFIDENCE',
                'post_graduation_total_marks','post_graduation_total_marks_CONFIDENCE',
                'post_graduation_marks_obtained','post_graduation_marks_obtained_CONFIDENCE',
                'post_graduation_passing_year','post_graduation_passing_year_CONFIDENCE',
                'account_number','account_number_CONFIDENCE']
# alpha_numeric = ['present_address','email','disability','father_email_id','mother_email_id','ifsc_code',
#                  'relation_with_account_holder']

# %%
processed_json = {
        "mother_email_id_CONFIDENCE": 0.43888889087571037,
        "mother_email_id": " 1 ",
        "mother_occupation_CONFIDENCE": 0.4233333244919777,
        "mother_occupation": " HOUSEWIFE",
        "total_marks_CONFIDENCE": 0.949999988079071,
        "total_marks": " ",
        "first_name_CONFIDENCE": 0.8080000042915344,
        "first_name": "SNEHATI 1241",
        "last_name_CONFIDENCE": 0.48333333681027096,
        "last_name": "GHOUTHIAN SZERESSE HE",
        "mother_annual_income_CONFIDENCE": 0.6216666748126348,
        "mother_annual_income": " ",
        "mother_last_name_CONFIDENCE": 0.6439999967813492,
        "mother_last_name": " ",
        "marks_obtained_CONFIDENCE": 0.4099999964237213,
        "marks_obtained": "U19 6",
        "previous_class_passing_year_CONFIDENCE": 0.3600000023841858,
        "previous_class_passing_year": " ",
        "father_mobile_number_CONFIDENCE": 0.3700000047683716,
        "father_mobile_number": "610 ",
        "father_occupation_CONFIDENCE": 0.699999988079071,
        "father_occupation": "PRIVATE TOBI",
        "student_mobile_number_CONFIDENCE": 0.4712500059977174,
        "student_mobile_number": " 45845197 L1",
        "date_of_birth_CONFIDENCE": 0.7599999904632568,
        "date_of_birth": "23102004",
        "present_address_CONFIDENCE": 0.519090910018845,
        "present_address": " T TiT F T 1 li 1 NEW TILPAT COLONY HANI PANTAL Y 4 FENIL PATI COLOMYHMISPALLA 4 ",
        "father_first_name_CONFIDENCE": 0.47000000160187483,
        "father_first_name": "F BHALWA NT",
        "aadhar_number_CONFIDENCE": 0.6885714312749249,
        "aadhar_number": " Rg x2",
        "percentage_of_disability_CONFIDENCE": 0.4475000109523535,
        "percentage_of_disability": "F ",
        "annual_fee_CONFIDENCE": 0.4000000059604645,
        "annual_fee": " ",
        "father_annual_income_CONFIDENCE": 0.43666666684051353,
        "father_annual_income": "JE ",
        "mother_first_name_CONFIDENCE": 0.6318181888623671,
        "mother_first_name": " TARATI",
        "father_email_id_CONFIDENCE": 0.43210526242067937,
        "father_email_id": " F rl L li ",
        "email_CONFIDENCE": 0.4921518994283073,
        "email": " I l lineil i",
        "gender": "female",
        "number_of_brothers_sisters": "1",
        "religion": "hindu",
        "category": "general",
        "present_class": "11",
        "present_class_stream": "textfield,commerce,arts",
        "mode_of_course": "parttime",
        "type_of_student": "studentdayscholar",
        "bank_name_CONFIDENCE": 0.699999988079071,
        "bank_name": "Tour Balik Detalls ",
        "graduation_marks_obtained_CONFIDENCE": 0.4816666642824809,
        "graduation_marks_obtained": " mrinn",
        "graduation_passing_year_CONFIDENCE": 0.5291666664804021,
        "graduation_passing_year": " ",
        "account_holder_name_CONFIDENCE": 0.3465384633208697,
        "account_holder_name": " FS F 11 ",
        "class_10_total_marks_CONFIDENCE": 0.27000001072883606,
        "class_10_total_marks": " ",
        "account_number_CONFIDENCE": 0.4526666688422362,
        "account_number": "11 CE L",
        "post_graduation_passing_year_CONFIDENCE": 0.1599999964237213,
        "post_graduation_passing_year": "1",
        "relation_with_account_holder_CONFIDENCE": 0.534749998524785,
        "relation_with_account_holder": " E ",
        "post_graduation_stream": "Science,Arts,OthersTextField"
    }

# %%
for i in alphabets_only:
    if i in processed_json:

        if i.rsplit("_")[-1] =="CONFIDENCE":
            processed_json[i] = processed_json[i]/3
            print(i)
        else:
            # print(i)
            result = ''.join([j for j in processed_json[i] if not j.isdigit()]).strip()
    #         print(result_text+"\n")
            processed_json[i] = result

for i in numeric_only:
    if i in processed_json:
#         print(i)
#         print("Original Value: {}".format(processed_json[i]))
        
        if i.rsplit("_")[-1] =="CONFIDENCE":
            processed_json[i] = processed_json[i]/3
        else:
            result = ''.join([j for j in processed_json[i] if not j.isalpha()]).strip()
#         print("Trimmed Value: {}\n".format(result))
            processed_json[i] = result
# Out:
# first_name_CONFIDENCE
# last_name_CONFIDENCE
# father_first_name_CONFIDENCE
# father_occupation_CONFIDENCE
# mother_first_name_CONFIDENCE
# mother_last_name_CONFIDENCE
# mother_occupation_CONFIDENCE
# bank_name_CONFIDENCE
# account_holder_name_CONFIDENCE
# -----------------------------------------------------------------
# --------------------------------------------------------

# %%
processed_json
# Out:
# {'aadhar_number': '2',
#  'aadhar_number_CONFIDENCE': 0.22952381042497497,
#  'account_holder_name': 'FS F',
#  'account_holder_name_CONFIDENCE': 0.11551282110695656,
#  'account_number': '11',
#  'account_number_CONFIDENCE': 0.15088888961407873,
#  'annual_fee': '',
#  'annual_fee_CONFIDENCE': 0.13333333532015482,
#  'bank_name': 'Tour Balik Detalls',
#  'bank_name_CONFIDENCE': 0.23333332935969034,
#  'category': 'general',
#  'class_10_total_marks': '',
#  'class_10_total_marks_CONFIDENCE': 0.09000000357627869,
#  'date_of_birth': '23102004',
#  'date_of_birth_CONFIDENCE': 0.25333333015441895,
#  'email': ' I l lineil i',
#  'email_CONFIDENCE': 0.4921518994283073,
#  'father_annual_income': '',
#  'father_annual_income_CONFIDENCE': 0.1455555556135045,
#  'father_email_id': ' F rl L li ',
#  'father_email_id_CONFIDENCE': 0.43210526242067937,
#  'father_first_name': 'F BHALWA NT',
#  'father_first_name_CONFIDENCE': 0.15666666720062494,
#  'father_mobile_number': '610',
# ...

# %%
dict_append = {"1" : "Python", "2" : "Java"}

# %%
dict_append["2"] =dict_append["2"]+"_new"

# %%
dict_append
# Out:
# {'1': 'Python', '2': 'Java_new'}

# %%
# Out:
# {' ': '',
#  '1': '1',
#  '2': '2',
#  '4': '23102004',
#  '6': '19 6',
#  'E': 'HOUSEWIFE',
#  'I': 'TARATI',
#  'L': '11',
#  'T': 'F BHALWA NT',
#  'aadhar_number': ' Rg x2',
#  'aadhar_number_CONFIDENCE': 0.6885714312749249,
#  'account_holder_name': ' FS F 11 ',
#  'account_holder_name_CONFIDENCE': 0.3465384633208697,
#  'account_number': '11 CE L',
#  'account_number_CONFIDENCE': 0.4526666688422362,
#  'annual_fee': ' ',
#  'annual_fee_CONFIDENCE': 0.4000000059604645,
#  'bank_name': 'Tour Balik Detalls ',
#  'bank_name_CONFIDENCE': 0.699999988079071,
#  'category': 'general',
#  'class_10_total_marks': ' ',
#  'class_10_total_marks_CONFIDENCE': 0.27000001072883606,
#  'date_of_birth': '23102004',
#  'date_of_birth_CONFIDENCE': 0.7599999904632568,
#  'email': ' I l lineil i',
#  'email_CONFIDENCE': 0.4921518994283073,
#  'father_annual_income': 'JE ',
#  'father_annual_income_CONFIDENCE': 0.43666666684051353,
#  'father_email_id': ' F rl L li ',
# ...

# %%
for i in processed_json:
#     print(i)
    if i.rsplit("_")[-1] =="CONFIDENCE":
        print(i)
# Out:
# present_address_CONFIDENCE
# account_holder_name_CONFIDENCE
# mother_occupation_CONFIDENCE
# last_name_CONFIDENCE
# marks_obtained_CONFIDENCE
# father_email_id_CONFIDENCE
# father_occupation_CONFIDENCE
# email_CONFIDENCE
# aadhar_number_CONFIDENCE
# date_of_birth_CONFIDENCE
# percentage_of_disability_CONFIDENCE
# bank_name_CONFIDENCE
# mother_last_name_CONFIDENCE
# father_mobile_number_CONFIDENCE
# father_first_name_CONFIDENCE
# class_10_total_marks_CONFIDENCE
# graduation_marks_obtained_CONFIDENCE
# student_mobile_number_CONFIDENCE
# mother_first_name_CONFIDENCE
# relation_with_account_holder_CONFIDENCE
# mother_email_id_CONFIDENCE
# graduation_passing_year_CONFIDENCE
# account_number_CONFIDENCE
# previous_class_passing_year_CONFIDENCE
# mother_annual_income_CONFIDENCE
# total_marks_CONFIDENCE
# annual_fee_CONFIDENCE
# father_annual_income_CONFIDENCE
# first_name_CONFIDENCE
# post_graduation_passing_year_CONFIDENCE
